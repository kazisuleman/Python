# %%
import numpy as np
a = np.random.rand(4,2)
b = np.random.rand(4,2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#subsetting

# %%
a
# Out:
# array([[0.23506869, 0.37010259],
#        [0.8455326 , 0.13326724],
#        [0.63130839, 0.71677322],
#        [0.97727475, 0.01842392]])

# %%
a[2] #Select the element at the 2nd index
# Out:
# array([0.63130839, 0.71677322])

# %%
a[2,1] #Select the element at row 1 column 2 (equivalent to b[1][2])
# Out:
# 0.7167732234282742

# %%
#Slicing [start:stop]

# %%
my_list = [1, 2, 3, 4, 5]

print(my_list[:])
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list[2:]
# Out:
# [3, 4, 5]

# %%
my_list[3:]
# Out:
# [4, 5]

# %%
my_list[:-1]
# Out:
# [1, 2, 3, 4]

# %%
my_list[-1:]
# Out:
# [5]

# %%
a[0:2,0:1] #Select items at index 0 and 1
# Out:
# array([[0.23506869],
#        [0.8455326 ]])

# %%
a[2,0]
# Out:
# 0.6313083882915161

# %%
x = np.random.random((3, 3, 3))

# %%
x
# Out:
# array([[[0.29096389, 0.00562103, 0.85570289],
#         [0.81954915, 0.34612493, 0.90804963],
#         [0.85227918, 0.71468238, 0.26058969]],
#
#        [[0.8537133 , 0.3946384 , 0.41717069],
#         [0.75482232, 0.80383026, 0.27532675],
#         [0.32475818, 0.83852685, 0.05700193]],
#
#        [[0.66302083, 0.85763872, 0.39113416],
#         [0.06267025, 0.7316895 , 0.80912234],
#         [0.12948779, 0.37671539, 0.81892713]]])

# %%
x[2,1]
# Out:
# array([0.06267025, 0.7316895 , 0.80912234])

# %%
x[2,1,1]
# Out:
# 0.7316894972956318
