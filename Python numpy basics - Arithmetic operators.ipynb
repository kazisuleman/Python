# %%
import numpy as np
#np.info(np.ndarray.dtype)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = np.random.rand(4, 2)
b = np.random.rand(4, 2)

# %%
sub  = a - b
sub
# Out:
# array([[-0.6065664 ,  0.55961945],
#        [-0.7015085 ,  0.0565851 ],
#        [ 0.13484642,  0.4772078 ],
#        [ 0.23831155,  0.24689934]])

# %%
sub = np.subtract(a,b)
sub
# Out:
# array([[-0.6065664 ,  0.55961945],
#        [-0.7015085 ,  0.0565851 ],
#        [ 0.13484642,  0.4772078 ],
#        [ 0.23831155,  0.24689934]])
