# %%
#Inspecting Your Array

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
a = [100, 200, 300, 400],
print(a)
# Out:
# ([100, 200, 300, 400],)

# %%
b = np.random.rand(4,2)
b
# Out:
# array([[0.82489387, 0.81239963],
#        [0.02151139, 0.6144878 ],
#        [0.40022246, 0.58037414],
#        [0.97987212, 0.05179109]])

# %%
c = np.random.rand(4,2,3)
print(c)
# Out:
# [[[0.10468975 0.47779506 0.50034974]
#   [0.8140218  0.81172587 0.49038949]]
#
#  [[0.62254863 0.90117834 0.72768689]
#   [0.55378486 0.62516509 0.458594  ]]
#
#  [[0.79733404 0.58057238 0.83226206]
#   [0.13078572 0.38907671 0.91444941]]
#
#  [[0.20023882 0.48112939 0.14431539]
#   [0.22125757 0.40747442 0.23981962]]]

# %%
b.shape
# Out:
# (4, 2)

# %%
len(b)
# Out:
# 4

# %%
b.ndim
# Out:
# 2

# %%
b.size
# Out:
# 8

# %%
b.dtype
# Out:
# dtype('float64')

# %%
b.dtype.name
# Out:
# 'float64'

# %%
#b = int(b)
b = np.floor(b)
b
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
b = b.astype(int)
b
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 0],
#        [0, 0]])
