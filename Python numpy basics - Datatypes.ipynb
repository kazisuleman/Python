# %%
#Write a program to create numpy array

# %%
import numpy as np
a = np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
b = np.array([(1.5,2,3), (4,5,6)], dtype = float)
b
# Out:
# array([[1.5, 2. , 3. ],
#        [4. , 5. , 6. ]])

# %%
c = np.array([[(1.5,2,3), (4,5,6)], [(3,2,1), (4,5,6)]],dtype = float)
c
# Out:
# array([[[1.5, 2. , 3. ],
#         [4. , 5. , 6. ]],
#
#        [[3. , 2. , 1. ],
#         [4. , 5. , 6. ]]])

# %%
#Data types conversion Ref: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d = np.int64
d
# Out:
# numpy.int64

# %%
e = np.float32
e
# Out:
# numpy.float32

# %%
f = np.bool_
f
# Out:
# numpy.bool_

# %%
g = np.int_ 
g
# Out:
# numpy.int32

# %%
h = np.float64
h
# Out:
# numpy.float64

# %%
i = np.complex128
i
# Out:
# numpy.complex128

# %%
l = np.object_
l
# Out:
# numpy.object_

# %%
m = np.longlong
m
# Out:
# numpy.int64

# %%
n = np.int_
n
# Out:
# numpy.int32

# %%
o = np.unicode_
o
# Out:
# numpy.str_
